# %% [markdown]
# ## UDEMY COURSE DATA ANALYSIS PYTHON EXCERCISE
#
# Objective :<br>
# Q. 1) What are all different subjects for which Udemy is offering courses ? <br>
# Q. 2) Which subject has the maximum number of courses.<br>
# Q. 3) Show all the courses which are Free of Cost.<br>
# Q. 4) Show all the courses which are Paid. <br>
# Q. 5) Which are Top Selling Courses ?<br>
# Q. 6) Which are Least Selling Courses ? <br>
# Q. 7) Show all courses of Graphic Design where the price is below 100 ?<br>
# Q. 8) List out all the courses that are related to 'Python'.<br>
# Q. 9) What are courses that were published in the year 2015 ?<br>
# Q. 10) What is the Max. Number of Subscribers for Each Level of courses ?<br>

# %%
#Library Declaration
import pandas as pd

# %% [markdown]
# Importing data procedure

# %%
df = pd.read_csv("Udemy.csv")

# %% [markdown]
# Basic data exploration to familiarized the data we are working on

# %%
df.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %% [markdown]
# ## Listing Subjects in Udemy

# %%
df["subject"].value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# From above code can be concluded there are **4 Subjects** covered in Udemy with **Web Development** has the maximum number of courses

# %% [markdown]
# ## Evaluating Paid or Free Course

# %%
#Showing Free Course
df[df["is_paid"]==0].reset_index()
# Out:
#      index  course_id                                       course_title  \
# 0       41     286070        5 lecciones que todo guitarrista debe tomar
# 1       49     696630  7 Ways A Beginner Guitarist Can Sound Better, ...
# 2       57     955914  A beginner`s guide to fingerpicking and strumm...
# 3       67     270976                             A how to guide in HTML
# 4       74    1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...
# ..     ...        ...                                                ...
# 305   3620     552598  WordPress in under an hour - Create/manage you...
# 306   3638    1068590                     Wordpress Website Mastery 2017
# 307   3652     752706  Write quicker HTML5 and CSS 3; productivity ha...
# 308   3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...
# 309   3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...
#
#      is_paid price  num_subscribers  num_reviews  num_lectures  \
# ...

# %%
#Showing Paid Course
df[df["is_paid"]==1].reset_index()
# Out:
#       index  course_id                                       course_title  \
# 0         0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...
# 1         1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...
# 2         2    1193886  #12 Hand Coordination: Let your Hands dance wi...
# 3         3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...
# 4         4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...
# ...     ...        ...                                                ...
# 3367   3676     498488  Your First Successful Forex Trades - With Case...
# 3368   3677     328960  Your Own Site in 45 Min: The Complete Wordpres...
# 3369   3678     552700    Your Second Course on Piano: Two Handed Playing
# 3370   3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...
# 3371   3681     964478                Zombie Apocalypse Photoshop Actions
#
#       is_paid price  num_subscribers  num_reviews  num_lectures  \
# ...

# %%
#Top 10 most selling
df.sort_values('num_subscribers',ascending = False).head(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# 1388      19421              Free Beginner Electric Guitar Lessons    False
# 3556     473160  Web Design for Web Developers: Build Beautiful...    False
# 2233      94430             Learn Javascript & JQuery From Scratch     True
# 2886     130064  Practical PHP: Master the Basics and Code Dyna...    False
# 2034     364426          JavaScript: Understanding the Weird Parts     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.sort_values('num_subscribers',ascending = True).head(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 649     1233314                      Building a Balanced Scorecard     True
# 3259    1232282          The Cash Flow Statement - An Introduction     True
# 3261    1275872                    The Complete Adobe Spark Course     True
# 910      726314       Create Beautiful Image Maps for Your Website     True
# 3328     715476        The Cuckoo Strategy to get European Funding     True
# 1325    1187084  Forex how traders beat the markest with little...     True
# 2596     185526                             MicroStation - Células     True
# 2597     185526                             MicroStation - Células     True
# 848     1232390                                   Corporate Ethics     True
# 2900     995384  Professional Business Logo Design Using Free O...     True
#
#      price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
# Graphic Design Course cost less than 100
df['price'] = pd.to_numeric(df.price)
df[(df['subject']== 'Graphic Design') & (int(df.price) < 100)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Free"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23248\3430523622.py in <module>
#       1 # Graphic Design Course cost less than 100
# ----> 2 df['price'] = pd.to_numeric(df.price)
#       3 df[(df['subject']== 'Graphic Design') & (int(df.price) < 100)]
#
# C:\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
# ...
